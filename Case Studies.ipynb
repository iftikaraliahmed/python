# %%
# Random float
import numpy as np

np.random.seed(123)
rand_float=np.random.rand()
rand_float
# Out:
# 0.6964691855978616

# %%
#Roll the dice

array_int_1=np.random.randint(1,7)
print(array_int_1)
array_int_2=np.random.randint(1,7)
array_int_2
# Out:
# 2
# 2

# %%
#Determination of next move

def dicethrow():

        dice=0
        dice=np.random.randint(1,7)
        step_count=0

        if dice==1 or dice==2:
                step_count=step_count-1

        elif dice==3 or dice==4 or dice==5:
            step_count+=1
        else:
            dice=np.random.randint(1,7)
            print("Value", dice, "Count", step_count)

# %%
def dicethrow():
    random_walk=list()
    random_walk=[0]
    dice,upcount,step_count,total_count=0,0,0,0
    for i in range(1,101):
        dice=np.random.randint(1,7)
        step_count=random_walk[-1]
        if dice==1 or dice==2:
                step_count=max(0,step_count-1)
        elif dice==3 or dice==4 or dice==5:
                                        step_count+=1
        else:
                    step_count=step_count+np.random.randint(1,7)
                    random_walk.append(step_count)
                
        print(random_walk)
                
dicethrow()
# Out:
# [0]
# [0]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16]
# [0, 5, 11, 16, 18]
# [0, 5, 11, 16, 18]
# [0, 5, 11, 16, 18, 21]
# [0, 5, 11, 16, 18, 21]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23]
# [0, 5, 11, 16, 18, 21, 23, 26]
# [0, 5, 11, 16, 18, 21, 23, 26]
# ...

# %%
#all walk

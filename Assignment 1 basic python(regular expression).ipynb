# %%
import re

try:
    fhand=open('weblog.txt','r')
    print('File opened successfully')
except:
    print('File cannot be opened')
    exit()
# Out:
# File opened successfully

# %%
count=0
for line in fhand:
    count+=1
    print("Line number ",count,":", line)
    
print("Total lines=",count)
# Out:
# Line number  1 : 10.128.2.1	[29/Nov/2017:06:58:55	GET /login.php HTTP/1.1	200
#
# Line number  2 : 10.128.2.1	[29/Nov/2017:06:59:02	POST /process.php HTTP/1.1	302
#
# Line number  3 : 10.128.2.1	[29/Nov/2017:06:59:03	GET /home.php HTTP/1.1	200
#
# Line number  4 : 10.131.2.1	[29/Nov/2017:06:59:04	GET /js/vendor/moment.min.js HTTP/1.1	200
#
# Line number  5 : 10.130.2.1	[29/Nov/2017:06:59:06	GET /bootstrap-3.3.7/js/bootstrap.js HTTP/1.1	200
#
# Line number  6 : 10.130.2.1	[29/Nov/2017:06:59:19	GET /profile.php?user=bala HTTP/1.1	200
#
# Line number  7 : 10.128.2.1	[29/Nov/2017:06:59:19	GET /js/jquery.min.js HTTP/1.1	200
#
# Line number  8 : 10.131.2.1	[29/Nov/2017:06:59:19	GET /js/chart.min.js HTTP/1.1	200
#
# Line number  9 : 10.131.2.1	[29/Nov/2017:06:59:30	GET /edit.php?name=bala HTTP/1.1	200
#
# Line number  10 : 10.131.2.1	[29/Nov/2017:06:59:37	GET /logout.php HTTP/1.1	302
#
# Line number  11 : 10.131.2.1	[29/Nov/2017:06:59:37	GET /login.php HTTP/1.1	200
#
# ...

# %%
print('IP Address is: ',[line[0:10]])
# Out:
# IP Address is:  ['10.130.2.1']

# %%
fhand = open('weblog.txt','r')

# %%
ls=[]
for line in fhand:
    ls=line.split()
print(ls)
# Out:
# ['10.130.2.1', '[02/Mar/2018:15:47:46', 'GET', '/home.php', 'HTTP/1.1', '200']

# %%
for item in ls:
    
    print([item])
# Out:
# ['10.130.2.1']
# ['[02/Mar/2018:15:47:46']
# ['GET']
# ['/home.php']
# ['HTTP/1.1']
# ['200']

# %%
#a1 = [1, 'x', 'y']  
#a2 = [1, 'x', 'y']  
#a3 = [1, 'x', 'y']

#b = [2, 3]

#a1.append(b)  
#a2.insert(3, b)  
#a3.extend(b)

#print(a1)  
#print(a2)  
#print(a3) 

#[1, 'x', 'y', [2, 3]]
#[1, 'x', 'y', [2, 3]]
#[1, 'x', 'y', 2, 3]
# Out:
# [['200']]

# %%
# Out:
# []

# %%
import pandas as pd
euro_leagues = pd.read_csv('D:/Manipal Data Science/First Term/NumPy/goal_stats_euro_leagues_2012-13.csv')
euro_leagues.head()
# Out:
#         Month           Stat   EPL  La Liga  Serie A  Bundesliga
# 0  08/01/2012  MatchesPlayed  20.0       20     10.0        10.0
# 1  09/01/2012  MatchesPlayed  38.0       39     50.0        44.0
# 2  10/01/2012  MatchesPlayed  31.0       31     39.0        27.0
# 3  11/01/2012  MatchesPlayed  50.0       41     42.0        46.0
# 4  12/01/2012  MatchesPlayed  59.0       39     39.0        26.0

# %%
euro_leagues = euro_leagues.set_index(['Month','Stat'])

# %%
euro_leagues
# Out:
#                             EPL  La Liga  Serie A  Bundesliga
# Month      Stat
# 08/01/2012 MatchesPlayed   20.0       20     10.0        10.0
# 09/01/2012 MatchesPlayed   38.0       39     50.0        44.0
# 10/01/2012 MatchesPlayed   31.0       31     39.0        27.0
# 11/01/2012 MatchesPlayed   50.0       41     42.0        46.0
# 12/01/2012 MatchesPlayed   59.0       39     39.0        26.0
# 01/01/2013 MatchesPlayed   42.0       40     40.0        18.0
# 02/01/2013 MatchesPlayed   30.0       40     40.0        36.0
# 03/01/2013 MatchesPlayed   35.0       38     39.0        36.0
# 04/01/2013 MatchesPlayed   42.0       42     41.0        36.0
# 05/01/2013 MatchesPlayed   33.0       40     40.0        27.0
# 06/02/2013 MatchesPlayed    NaN       10      NaN         NaN
# 08/01/2012 GoalsScored     57.0       60     21.0        23.0
# 09/01/2012 GoalsScored    111.0      112    133.0       135.0
# 10/01/2012 GoalsScored     95.0       88     97.0        77.0
# ...

# %%
euro_multiindex = euro_leagues.groupby(level=['Month','Stat'])
euro_multiindex

# %%
euro_multiindex.groups
# Out:
# {('01/01/2013',
#   'GoalsScored'): MultiIndex(levels=[['01/01/2013', '02/01/2013', '03/01/2013', '04/01/2013', '05/01/2013', '06/01/2013', '06/02/2013', '08/01/2012', '09/01/2012', '10/01/2012', '11/01/2012', '12/01/2012'], ['GoalsScored', 'MatchesPlayed']],
#             labels=[[0], [0]],
#             names=['Month', 'Stat']),
#  ('01/01/2013',
#   'MatchesPlayed'): MultiIndex(levels=[['01/01/2013', '02/01/2013', '03/01/2013', '04/01/2013', '05/01/2013', '06/01/2013', '06/02/2013', '08/01/2012', '09/01/2012', '10/01/2012', '11/01/2012', '12/01/2012'], ['GoalsScored', 'MatchesPlayed']],
#             labels=[[0], [1]],
#             names=['Month', 'Stat']),
#  ('02/01/2013',
#   'GoalsScored'): MultiIndex(levels=[['01/01/2013', '02/01/2013', '03/01/2013', '04/01/2013', '05/01/2013', '06/01/2013', '06/02/2013', '08/01/2012', '09/01/2012', '10/01/2012', '11/01/2012', '12/01/2012'], ['GoalsScored', 'MatchesPlayed']],
#             labels=[[1], [0]],
# ...

# %%
for name,group in euro_multiindex:
    print(name)
    print(group)
    print("\n")
# Out:
# ('01/01/2013', 'GoalsScored')
#                           EPL  La Liga  Serie A  Bundesliga
# Month      Stat
# 01/01/2013 GoalsScored  117.0      121    104.0        51.0
#
#
# ('01/01/2013', 'MatchesPlayed')
#                            EPL  La Liga  Serie A  Bundesliga
# Month      Stat
# 01/01/2013 MatchesPlayed  42.0       40     40.0        18.0
#
#
# ('02/01/2013', 'GoalsScored')
#                          EPL  La Liga  Serie A  Bundesliga
# Month      Stat
# 02/01/2013 GoalsScored  87.0      110    100.0       101.0
#
#
# ('02/01/2013', 'MatchesPlayed')
#                            EPL  La Liga  Serie A  Bundesliga
# Month      Stat
# 02/01/2013 MatchesPlayed  30.0       40     40.0        36.0
#
#
# ('03/01/2013', 'GoalsScored')
#                          EPL  La Liga  Serie A  Bundesliga
# Month      Stat
# 03/01/2013 GoalsScored  91.0      101     99.0       106.0
#
#
# ('03/01/2013', 'MatchesPlayed')
#                            EPL  La Liga  Serie A  Bundesliga
# ...

# %%
euro_multiindex2 = euro_leagues.groupby(level='Stat')
euro_multiindex2.sum()
# Out:
#                   EPL  La Liga  Serie A  Bundesliga
# Stat
# GoalsScored    1063.0     1133   1003.0       898.0
# MatchesPlayed   380.0      380    380.0       306.0

# %%
euro_multiindex2 = euro_leagues.groupby(['Month','Stat'])
euro_multiindex2.sum()
# Out:
#                             EPL  La Liga  Serie A  Bundesliga
# Month      Stat
# 01/01/2013 GoalsScored    117.0      121    104.0        51.0
#            MatchesPlayed   42.0       40     40.0        18.0
# 02/01/2013 GoalsScored     87.0      110    100.0       101.0
#            MatchesPlayed   30.0       40     40.0        36.0
# 03/01/2013 GoalsScored     91.0      101     99.0       106.0
#            MatchesPlayed   35.0       38     39.0        36.0
# 04/01/2013 GoalsScored    105.0      127    102.0       104.0
#            MatchesPlayed   42.0       42     41.0        36.0
# 05/01/2013 GoalsScored     96.0      109    102.0        92.0
#            MatchesPlayed   33.0       40     40.0        27.0
# 06/01/2013 GoalsScored      0.0       80      0.0         0.0
# 06/02/2013 MatchesPlayed    0.0       10      0.0         0.0
# 08/01/2012 GoalsScored     57.0       60     21.0        23.0
#            MatchesPlayed   20.0       20     10.0        10.0
# ...

# %%
tot = euro_multiindex2.sum()
tot
# Out:
#                   EPL  La Liga  Serie A  Bundesliga
# Stat
# GoalsScored    1063.0     1133   1003.0       898.0
# MatchesPlayed   380.0      380    380.0       306.0

# %%
tot.loc['Goals_per_game'] = tot.loc['GoalsScored']/tot.loc['MatchesPlayed']
tot
# Out:
#                         EPL      La Liga      Serie A  Bundesliga
# Stat
# GoalsScored     1063.000000  1133.000000  1003.000000  898.000000
# MatchesPlayed    380.000000   380.000000   380.000000  306.000000
# Goals_per_game     2.797368     2.981579     2.639474    2.934641

# %%
grouping = tot.loc['GoalsScored']/tot.loc['MatchesPlayed']
grouping
# Out:
# EPL           2.797368
# La Liga       2.981579
# Serie A       2.639474
# Bundesliga    2.934641
# dtype: float64

# %%
grouping=pd.DataFrame(grouping).T
grouping
# Out:
#         EPL   La Liga   Serie A  Bundesliga
# 0  2.797368  2.981579  2.639474    2.934641

# %%
goals_per_game = grouping.rename(index={0:'Goals_per_Game'})
goals_per_game
# Out:
#                      EPL   La Liga   Serie A  Bundesliga
# Goals_per_Game  2.797368  2.981579  2.639474    2.934641

# %%
tot = tot.drop('GoalsScored',axis=0)
tot
# Out:
#                        EPL     La Liga     Serie A  Bundesliga
# Stat
# MatchesPlayed   380.000000  380.000000  380.000000  306.000000
# Goals_per_game    2.797368    2.981579    2.639474    2.934641

# %%
tot=tot.drop(['La Liga','Serie A'], axis=1)
tot
# Out:
#                        EPL  Bundesliga
# Stat
# MatchesPlayed   380.000000  306.000000
# Goals_per_game    2.797368    2.934641

# %%
tot.drop_duplicates()
# Out:
#                        EPL  Bundesliga
# Stat
# MatchesPlayed   380.000000  306.000000
# Goals_per_game    2.797368    2.934641

# %%
euro_multiindex2 = euro_leagues.groupby(level='Stat')
euro_multiindex2

# %%
import numpy as np
euro_multiindex2.sum()
euro_multiindex2.aggregate(np.sum)
# Out:
#                   EPL  La Liga  Serie A  Bundesliga
# Stat
# GoalsScored    1063.0     1133   1003.0       898.0
# MatchesPlayed   380.0      380    380.0       306.0

# %%
euro_multiindex2.aggregate([np.sum,np.mean])
# Out:
#                   EPL        La Liga             Serie A        Bundesliga  \
#                   sum   mean     sum        mean     sum   mean        sum
# Stat
# GoalsScored    1063.0  106.3    1133  103.000000  1003.0  100.3      898.0
# MatchesPlayed   380.0   38.0     380   34.545455   380.0   38.0      306.0
#
#
#                mean
# Stat
# GoalsScored    89.8
# MatchesPlayed  30.6

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('D:/Manipal Data Science/First Term/NumPy/euro_winners.csv')
df.head()
# Out:
#     Season Nation      Winners Score           Runners-up Runner-UpNation  \
# 0  1955–56  Spain  Real Madrid   4–3       Stade de Reims          France
# 1  1956–57  Spain  Real Madrid   2–0           Fiorentina           Italy
# 2  1957–58  Spain  Real Madrid   3–2                Milan           Italy
# 3  1958–59  Spain  Real Madrid   2–0       Stade de Reims          France
# 4  1959–60  Spain  Real Madrid   7–3  Eintracht Frankfurt         Germany
#
#                                Venue  Attendance
# 0             Parc des Princes,Paris       38239
# 1  Santiago Bernabéu Stadium, Madrid      124000
# 2            Heysel Stadium,Brussels       67000
# 3            Neckarstadion,Stuttgart       72000
# 4               Hampden Park,Glasgow      127621

# %%
df.set_index('Nation')
# Out:
#               Season            Winners    Score                Runners-up  \
# Nation
# Spain        1955–56        Real Madrid      4–3            Stade de Reims
# Spain        1956–57        Real Madrid      2–0                Fiorentina
# Spain        1957–58        Real Madrid      3–2                     Milan
# Spain        1958–59        Real Madrid      2–0            Stade de Reims
# Spain        1959–60        Real Madrid      7–3       Eintracht Frankfurt
# Portugal     1960–61            Benfica      3–2                 Barcelona
# Portugal     1961–62            Benfica      5–3               Real Madrid
# Italy        1962–63              Milan      2–1                   Benfica
# Italy        1963–64     Internazionale      3–1               Real Madrid
# Italy        1964–65     Internazionale      1–0                   Benfica
# Spain        1965–66        Real Madrid      2–1                  Partizan
# ...

# %%
df = df.groupby('Nation')

# %%
df.groups
# Out:
# {'England': Int64Index([12, 21, 22, 23, 24, 25, 26, 28, 43, 49, 52, 56], dtype='int64'),
#  'France': Int64Index([37], dtype='int64'),
#  'Germany': Int64Index([18, 19, 20, 27, 41, 45, 57], dtype='int64'),
#  'Italy': Int64Index([7, 8, 9, 13, 29, 33, 34, 38, 40, 47, 51, 54], dtype='int64'),
#  'Netherlands': Int64Index([14, 15, 16, 17, 32, 39], dtype='int64'),
#  'Portugal': Int64Index([5, 6, 31, 48], dtype='int64'),
#  'Romania': Int64Index([30], dtype='int64'),
#  'Scotland': Int64Index([11], dtype='int64'),
#  'Spain': Int64Index([0, 1, 2, 3, 4, 10, 36, 42, 44, 46, 50, 53, 55], dtype='int64'),
#  'Yugoslavia': Int64Index([35], dtype='int64')}

# %%
df.count()

# %%
df['Attendance'].agg({'Total':np.sum,'Average':np.mean,'Std_deviation':np.std})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#               Total       Average  Std_deviation
# Nation
# England      798411  66534.250000   17091.309877
# France        64400  64400.000000            NaN
# Germany      473083  67583.285714   13783.830076
# Italy        789135  65761.250000   17443.516494
# Netherlands  404934  67489.000000   16048.580972
# Portugal     198542  49635.500000   15632.863259
# Romania       70000  70000.000000            NaN
# Scotland      45000  45000.000000            NaN
# Spain        955203  73477.153846   27457.531064
# Yugoslavia    56000  56000.000000            NaN

# %%
import pandas as pd
euro_leagues = pd.read_csv('D:/Manipal Data Science/First Term/NumPy/goal_stats_euro_leagues_2012-13.csv')
euro_leagues.head()
# Out:
#         Month           Stat   EPL  La Liga  Serie A  Bundesliga
# 0  08/01/2012  MatchesPlayed  20.0       20     10.0        10.0
# 1  09/01/2012  MatchesPlayed  38.0       39     50.0        44.0
# 2  10/01/2012  MatchesPlayed  31.0       31     39.0        27.0
# 3  11/01/2012  MatchesPlayed  50.0       41     42.0        46.0
# 4  12/01/2012  MatchesPlayed  59.0       39     39.0        26.0

# %%
euro_leagues.set_index('Month')
# Out:
#                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012  MatchesPlayed   20.0       20     10.0        10.0
# 09/01/2012  MatchesPlayed   38.0       39     50.0        44.0
# 10/01/2012  MatchesPlayed   31.0       31     39.0        27.0
# 11/01/2012  MatchesPlayed   50.0       41     42.0        46.0
# 12/01/2012  MatchesPlayed   59.0       39     39.0        26.0
# 01/01/2013  MatchesPlayed   42.0       40     40.0        18.0
# 02/01/2013  MatchesPlayed   30.0       40     40.0        36.0
# 03/01/2013  MatchesPlayed   35.0       38     39.0        36.0
# 04/01/2013  MatchesPlayed   42.0       42     41.0        36.0
# 05/01/2013  MatchesPlayed   33.0       40     40.0        27.0
# 06/02/2013  MatchesPlayed    NaN       10      NaN         NaN
# 08/01/2012    GoalsScored   57.0       60     21.0        23.0
# 09/01/2012    GoalsScored  111.0      112    133.0       135.0
# 10/01/2012    GoalsScored   95.0       88     97.0        77.0
# ...

# %%
euro_leagues['Stat'] == 'GoalsScored'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# Name: Stat, dtype: bool

# %%
df3 = euro_leagues[euro_leagues['Stat'] == 'GoalsScored']
df3
# Out:
#          Month         Stat    EPL  La Liga  Serie A  Bundesliga
# 11  08/01/2012  GoalsScored   57.0       60     21.0        23.0
# 12  09/01/2012  GoalsScored  111.0      112    133.0       135.0
# 13  10/01/2012  GoalsScored   95.0       88     97.0        77.0
# 14  11/01/2012  GoalsScored  121.0      116    120.0       137.0
# 15  12/01/2012  GoalsScored  183.0      109    125.0        72.0
# 16  01/01/2013  GoalsScored  117.0      121    104.0        51.0
# 17  02/01/2013  GoalsScored   87.0      110    100.0       101.0
# 18  03/01/2013  GoalsScored   91.0      101     99.0       106.0
# 19  04/01/2013  GoalsScored  105.0      127    102.0       104.0
# 20  05/01/2013  GoalsScored   96.0      109    102.0        92.0
# 21  06/01/2013  GoalsScored    NaN       80      NaN         NaN

# %%
df3.iloc[:,1:]
# Out:
#            Stat    EPL  La Liga  Serie A  Bundesliga
# 11  GoalsScored   57.0       60     21.0        23.0
# 12  GoalsScored  111.0      112    133.0       135.0
# 13  GoalsScored   95.0       88     97.0        77.0
# 14  GoalsScored  121.0      116    120.0       137.0
# 15  GoalsScored  183.0      109    125.0        72.0
# 16  GoalsScored  117.0      121    104.0        51.0
# 17  GoalsScored   87.0      110    100.0       101.0
# 18  GoalsScored   91.0      101     99.0       106.0
# 19  GoalsScored  105.0      127    102.0       104.0
# 20  GoalsScored   96.0      109    102.0        92.0
# 21  GoalsScored    NaN       80      NaN         NaN

# %%
euro_leagues = euro_leagues.set_index('Month')

# %%
grpby_year = euro_leagues.groupby(lambda Month: Month.split('/')[2])
grpby_year

# %%
grpby_year.groups
# Out:
# {'2012': Index(['08/01/2012', '09/01/2012', '10/01/2012', '11/01/2012', '12/01/2012',
#         '08/01/2012', '09/01/2012', '10/01/2012', '11/01/2012', '12/01/2012'],
#        dtype='object', name='Month'),
#  '2013': Index(['01/01/2013', '02/01/2013', '03/01/2013', '04/01/2013', '05/01/2013',
#         '06/02/2013', '01/01/2013', '02/01/2013', '03/01/2013', '04/01/2013',
#         '05/01/2013', '06/01/2013'],
#        dtype='object', name='Month')}

# %%
grpby_year.count()
# Out:
#       Stat  EPL  La Liga  Serie A  Bundesliga
# 2012    10   10       10       10          10
# 2013    12   10       12       10          10

# %%
for name,group in grpby_year:
    print(name),
    print(group)
# Out:
# 2012
#                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012  MatchesPlayed   20.0       20     10.0        10.0
# 09/01/2012  MatchesPlayed   38.0       39     50.0        44.0
# 10/01/2012  MatchesPlayed   31.0       31     39.0        27.0
# 11/01/2012  MatchesPlayed   50.0       41     42.0        46.0
# 12/01/2012  MatchesPlayed   59.0       39     39.0        26.0
# 08/01/2012    GoalsScored   57.0       60     21.0        23.0
# 09/01/2012    GoalsScored  111.0      112    133.0       135.0
# 10/01/2012    GoalsScored   95.0       88     97.0        77.0
# 11/01/2012    GoalsScored  121.0      116    120.0       137.0
# 12/01/2012    GoalsScored  183.0      109    125.0        72.0
# 2013
#                      Stat    EPL  La Liga  Serie A  Bundesliga
# Month
# 01/01/2013  MatchesPlayed   42.0       40     40.0        18.0
# 02/01/2013  MatchesPlayed   30.0       40     40.0        36.0
# ...

# %%
na_fill = lambda x: x.fillna(x.mean())
transform = grpby_year.transform(na_fill)
transform
# Out:
#               EPL  La Liga  Serie A  Bundesliga
# Month
# 08/01/2012   20.0       20     10.0        10.0
# 09/01/2012   38.0       39     50.0        44.0
# 10/01/2012   31.0       31     39.0        27.0
# 11/01/2012   50.0       41     42.0        46.0
# 12/01/2012   59.0       39     39.0        26.0
# 01/01/2013   42.0       40     40.0        18.0
# 02/01/2013   30.0       40     40.0        36.0
# 03/01/2013   35.0       38     39.0        36.0
# 04/01/2013   42.0       42     41.0        36.0
# 05/01/2013   33.0       40     40.0        27.0
# 06/02/2013   67.8       10     70.7        60.7
# 08/01/2012   57.0       60     21.0        23.0
# 09/01/2012  111.0      112    133.0       135.0
# 10/01/2012   95.0       88     97.0        77.0
# 11/01/2012  121.0      116    120.0       137.0
# 12/01/2012  183.0      109    125.0        72.0
# 01/01/2013  117.0      121    104.0        51.0
# 02/01/2013   87.0      110    100.0       101.0
# ...
